# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcusTYHJ/CS315/blob/main/Cryption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Taking an input string of characters, no spaces, and outputting the Caesar Square decryption
import numpy as np
char = [104, 101, 121, 97, 108, 108]
cols = 3
rows = 2
matrix = np.array( [] )
matrix = np.append(matrix,char)
matrix.reshape(rows,cols)
# Out:
# array([[104., 101., 121.],
#        [ 97., 108., 108.]])

# %%
#Taking an input string of ASCII numbers, separated by spaces, and outputting the Caesar Cipher decryption.
StringofNums = input("Please type a string of number separated by spaces: ")
print(StringofNums)
StringofNums = StringofNums.split()
print(StringofNums)
for i in range(len(StringofNums)):
    num = (StringofNums[i])
    char_code = int(num)
    print(chr(char_code))
# Out:
# Please type a string of number separated by spaces: 104 103 105
# 104 103 105
# ['104', '103', '105']
# h
# g
# i

# %%
#Taking an input string of characters, separated by spaces, and outputting their corresponding ASCII numbers.
StringofChars = input("Please type a string of Charaters separated by spaces: ")
StringofChars = StringofChars.split()
for i in range(len(StringofChars)):
    Char = (StringofChars[i])
    ASCII_code = ord(Char)
    print(ASCII_code)
# Out:
# Please type a string of Charaters separated by spaces: m a r c u s
# 109
# 97
# 114
# 99
# 117
# 115
